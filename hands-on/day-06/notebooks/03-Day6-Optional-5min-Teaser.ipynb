# %%
# Databricks notebook source
# COMMAND ----------

BASE_PATH = "abfss://atininput@sadbtrng19032026.dfs.core.windows.net/data/"
STUDENT_ID = "u25"
DAY6_PREFIX = f"{BASE_PATH}day06-{STUDENT_ID}"

# COMMAND ----------

# %% [markdown]
# # Short add-on (not Day 6 items 17 or 18)
#
# Use if you have a few spare minutes after **01** and **02**. Otherwise skip.
#
# ---
#
# ## AQE

# %%
spark.conf.set("spark.sql.adaptive.enabled", "true")
spark.conf.set("spark.sql.adaptive.coalescePartitions.enabled", "true")
print(spark.conf.get("spark.sql.adaptive.enabled"))

# %% [markdown]
# ## Broadcast join
#
# Example: `large.join(small.hint("broadcast"), "key")` when the build side is small enough.

# %%
# Example: large.join(small.hint("broadcast"), "key")
spark.version

# %% [markdown]
# ## Where to read next
#
# Liquid clustering and data skipping: Delta docs for your DBR.
# Change data feed and streaming: Day 7.
